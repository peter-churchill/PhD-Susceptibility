# %%
#!pip install piecewise-regression
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting piecewise-regression
#   Downloading piecewise_regression-1.5.0-py3-none-any.whl.metadata (975 bytes)
# Requirement already satisfied: numpy in /home/pech2273/.local/lib/python3.12/site-packages (from piecewise-regression) (2.2.2)
# Requirement already satisfied: matplotlib in /home/pech2273/.local/lib/python3.12/site-packages (from piecewise-regression) (3.10.1)
# Requirement already satisfied: scipy in /home/pech2273/.local/lib/python3.12/site-packages (from piecewise-regression) (1.15.2)
# Collecting statsmodels (from piecewise-regression)
#   Downloading statsmodels-0.14.6-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (9.5 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /home/pech2273/.local/lib/python3.12/site-packages (from matplotlib->piecewise-regression) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /home/pech2273/.local/lib/python3.12/site-packages (from matplotlib->piecewise-regression) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/pech2273/.local/lib/python3.12/site-packages (from matplotlib->piecewise-regression) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/pech2273/.local/lib/python3.12/site-packages (from matplotlib->piecewise-regression) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.12/site-packages (from matplotlib->piecewise-regression) (23.2)
# Requirement already satisfied: pillow>=8 in /home/pech2273/.local/lib/python3.12/site-packages (from matplotlib->piecewise-regression) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/pech2273/.local/lib/python3.12/site-packages (from matplotlib->piecewise-regression) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.12/site-packages (from matplotlib->piecewise-regression) (2.9.0)
# Requirement already satisfied: pandas!=2.1.0,>=1.4 in /home/pech2273/.local/lib/python3.12/site-packages (from statsmodels->piecewise-regression) (2.2.3)
# Collecting patsy>=0.5.6 (from statsmodels->piecewise-regression)
#   Downloading patsy-1.0.2-py2.py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.12/site-packages (from pandas!=2.1.0,>=1.4->statsmodels->piecewise-regression) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/pech2273/.local/lib/python3.12/site-packages (from pandas!=2.1.0,>=1.4->statsmodels->piecewise-regression) (2025.2)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib->piecewise-regression) (1.16.0)
# Downloading piecewise_regression-1.5.0-py3-none-any.whl (24 kB)
# Downloading statsmodels-0.14.6-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (10.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.3/10.3 MB 44.6 MB/s eta 0:00:0000:010:01
# Downloading patsy-1.0.2-py2.py3-none-any.whl (233 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.3/233.3 kB 36.2 MB/s eta 0:00:00
# Installing collected packages: patsy, statsmodels, piecewise-regression
# Successfully installed patsy-1.0.2 piecewise-regression-1.5.0 statsmodels-0.14.6

# %%
import PeterChurchillFunctions as Function
import xarray as xr
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
from scipy.special import erf
import statsmodels.api as sm
from scipy.odr import ODR, Model, RealData
from matplotlib.colors import LogNorm
from sklearn.cluster import KMeans
from scipy import optimize
import pylab as pl
